# %%
# Pull in Dependences
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load the Data

# %%
# Load Airbnb listings data from CSV file
airbnb_data = pd.read_csv('Resources/raw_airbnb_listings_usa.csv', dtype={'neighbourhood_group': str})

# Display the first few rows of the data
airbnb_data.head()
# Out:
#    Unnamed: 0      id                                               name  \
# 0           0  183319                  Panoramic Ocean View Venice Beach
# 1           1     109  Amazing bright elegant condo park front *UPGRA...
# 2           2   51307  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 3           3  184314                    Boho Chic Flat..Steps to Beach!
# 4           4   51498  Guest House With Its Own Entrance/Exit and Hot...
#
#    host_id  host_name  neighbourhood_group    neighbourhood  latitude  \
# 0   867995  Barbara X  City of Los Angeles           Venice  33.99211
# 1      521      Paolo         Other Cities      Culver City  33.98301
# 2   235568      David  City of Los Angeles  Atwater Village  34.12206
# 3   884031     Ashley  City of Los Angeles           Venice  33.97487
# 4   236758        Bay  City of Los Angeles        Mar Vista  34.00389
#
#    longitude        room_type  ...  minimum_nights  number_of_reviews  \
# 0 -118.47600  Entire home/apt  ...              30                  3
# 1 -118.38607  Entire home/apt  ...              30                  2
# 2 -118.26783  Entire home/apt  ...              30                138
# 3 -118.46312  Entire home/apt  ...              30                 30
# 4 -118.44126  Entire home/apt  ...               3                378
#
#    last_review reviews_per_month  calculated_host_listings_count  \
# 0   2019-02-25              0.02                               2
# 1   2016-05-15              0.01                               1
# 2   2020-12-13              0.98                               2
# 3   2017-12-24              0.22                               1
# 4   2022-08-21              2.60                               1
#
#    availability_365  number_of_reviews_ltm       license state         city
# 0                 0                      0           NaN    CA  Los Angeles
# 1               139                      0           NaN    CA  Los Angeles
# 2               224                      0           NaN    CA  Los Angeles
# 3                 0                      0           NaN    CA  Los Angeles
# 4               348                     41  HSR19-001336    CA  Los Angeles
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Inspect the Data

# %%
# Display data information
airbnb_data.info()

# Check for missing values
airbnb_data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325858 entries, 0 to 325857
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      325858 non-null  int64
#  1   id                              325858 non-null  int64
#  2   name                            325839 non-null  object
#  3   host_id                         325858 non-null  int64
#  4   host_name                       324714 non-null  object
#  5   neighbourhood_group             155047 non-null  object
#  6   neighbourhood                   325146 non-null  object
#  7   latitude                        325858 non-null  float64
#  8   longitude                       325858 non-null  float64
#  9   room_type                       325858 non-null  object
#  10  price                           325858 non-null  int64
#  11  minimum_nights                  325858 non-null  int64
#  12  number_of_reviews               325858 non-null  int64
#  13  last_review                     263166 non-null  object
#  14  reviews_per_month               263166 non-null  float64
#  15  calculated_host_listings_count  325858 non-null  int64
#  16  availability_365                325858 non-null  int64
#  17  number_of_reviews_ltm           325858 non-null  int64
#  18  license                         86635 non-null   object
#  19  state                           325858 non-null  object
#  20  city                            325858 non-null  object
# dtypes: float64(3), int64(9), object(9)
# memory usage: 52.2+ MB
# Unnamed: 0                             0
# id                                     0
# name                                  19
# host_id                                0
# host_name                           1144
# neighbourhood_group               170811
# neighbourhood                        712
# latitude                               0
# longitude                              0
# room_type                              0
# price                                  0
# minimum_nights                         0
# number_of_reviews                      0
# last_review                        62692
# reviews_per_month                  62692
# calculated_host_listings_count         0
# availability_365                       0
# number_of_reviews_ltm                  0
# license                           239223
# state                                  0
# city                                   0
# dtype: int64

# %% [markdown]
# ### Handling Missing Values

# %%
# Fill missing values in 'reviews_per_month' with 0
airbnb_data['reviews_per_month'].fillna(0, inplace=True)

# Drop rows with missing values in crucial columns (e.g., 'name', 'host_id')
airbnb_data.dropna(subset=['name', 'host_id'], inplace=True)

# Verify missing values handling
airbnb_data.isnull().sum()
# Out:
# C:\Users\Bryan Hamilton-Brown\AppData\Local\Temp\ipykernel_18644\3082303304.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_data['reviews_per_month'].fillna(0, inplace=True)
# Unnamed: 0                             0
# id                                     0
# name                                   0
# host_id                                0
# host_name                           1144
# neighbourhood_group               170809
# neighbourhood                        712
# latitude                               0
# longitude                              0
# room_type                              0
# price                                  0
# minimum_nights                         0
# number_of_reviews                      0
# last_review                        62680
# reviews_per_month                      0
# calculated_host_listings_count         0
# availability_365                       0
# number_of_reviews_ltm                  0
# license                           239204
# state                                  0
# city                                   0
# dtype: int64

# %% [markdown]
# ### Format Consistences

# %%
# Ensure data types are consistent
airbnb_data['last_review'] = pd.to_datetime(airbnb_data['last_review'], errors='coerce')

# Check data types
airbnb_data.dtypes
# Out:
# Unnamed: 0                                 int64
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# license                                   object
# state                                     object
# city                                      object
# dtype: object

# %% [markdown]
# ### Remove Duplicates

# %%
# Check for duplicates
airbnb_data.duplicated().sum()

# Remove duplicates
airbnb_data.drop_duplicates(inplace=True)

# Verify removal of duplicates
airbnb_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Remove Irrelevant Columns

# %%
# Define the relevant columns for analysis
relevant_columns = [
    'id', 'name', 'host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
    'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews',
    'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365'
]

# Select only the relevant columns
airbnb_data = airbnb_data[relevant_columns]

# Verify the columns
airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 325839 entries, 0 to 325857
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              325839 non-null  int64
#  1   name                            325839 non-null  object
#  2   host_id                         325839 non-null  int64
#  3   neighbourhood_group             155030 non-null  object
#  4   neighbourhood                   325127 non-null  object
#  5   latitude                        325839 non-null  float64
#  6   longitude                       325839 non-null  float64
#  7   room_type                       325839 non-null  object
#  8   price                           325839 non-null  int64
#  9   minimum_nights                  325839 non-null  int64
#  10  number_of_reviews               325839 non-null  int64
#  11  last_review                     263159 non-null  datetime64[ns]
#  12  reviews_per_month               325839 non-null  float64
#  13  calculated_host_listings_count  325839 non-null  int64
#  14  availability_365                325839 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(4)
# memory usage: 39.8+ MB

# %% [markdown]
# ### Filter Data based on Number of Reviews

# %%
# Set the threshold for the minimum number of reviews
min_reviews_threshold = 100

# Filter the data to include only listings with at least 'min_reviews_threshold' reviews
filtered_airbnb_data = airbnb_data[airbnb_data['number_of_reviews'] >= min_reviews_threshold].copy()

# Verify the filtering
filtered_airbnb_data.info()

# Display the first few rows of the filtered data
filtered_airbnb_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38907 entries, 2 to 325827
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38907 non-null  int64
#  1   name                            38907 non-null  object
#  2   host_id                         38907 non-null  int64
#  3   neighbourhood_group             15314 non-null  object
#  4   neighbourhood                   38817 non-null  object
#  5   latitude                        38907 non-null  float64
#  6   longitude                       38907 non-null  float64
#  7   room_type                       38907 non-null  object
#  8   price                           38907 non-null  int64
#  9   minimum_nights                  38907 non-null  int64
#  10  number_of_reviews               38907 non-null  int64
#  11  last_review                     38907 non-null  datetime64[ns]
#  12  reviews_per_month               38907 non-null  float64
#  13  calculated_host_listings_count  38907 non-null  int64
#  14  availability_365                38907 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(4)
# memory usage: 4.7+ MB
#         id                                               name  host_id  \
# 2    51307  Spanish Bungalow Guest House LA CA. 30 plus ni...   235568
# 4    51498  Guest House With Its Own Entrance/Exit and Hot...   236758
# 9    51546                  Cool Pad Under the Hollywood Sign   237114
# 11  187526                   Malibu Pacific Ocean View Room 1   215462
# 12   52871          Beverly Hills Large 1-Bdr Near Everything   245280
#
#     neighbourhood_group    neighbourhood  latitude  longitude  \
# 2   City of Los Angeles  Atwater Village  34.12206 -118.26783
# 4   City of Los Angeles        Mar Vista  34.00389 -118.44126
# 9   City of Los Angeles  Hollywood Hills  34.11874 -118.32113
# 11         Other Cities           Malibu  34.03073 -118.75513
# 12         Other Cities    Beverly Hills  34.06118 -118.39804
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 2   Entire home/apt     75              30                138  2020-12-13
# 4   Entire home/apt    189               3                378  2022-08-21
# 9   Entire home/apt    100              31                188  2022-04-29
# 11     Private room    350               2                196  2022-08-24
# 12  Entire home/apt    165               5                130  2022-08-16
#
#     reviews_per_month  calculated_host_listings_count  availability_365
# 2                0.98                               2               224
# 4                2.60                               1               348
# 9                1.30                               1               250
# 11               1.58                               4               365
# 12               0.93                               1               259

# %% [markdown]
# ### Sort Data

# %%
# Sort the data based on 'number_of_reviews' in descending order
filtered_airbnb_data.sort_values(by='number_of_reviews', ascending=False, inplace=True)

# Display the first few rows of the sorted data
filtered_airbnb_data
# Out:
#               id                                               name  \
# 186785  29819757   Hotel Perks - Private Bedroom | Private Bathroom
# 125702      8357  The Mushroom Dome Retreat & LAND of Paradise S...
# 63769   42409434                               The Burlington Hotel
# 17954   42409434                               The Burlington Hotel
# 222414  35158303                     SAHARA Las Vegas, Marra 1 King
# ...          ...                                                ...
# 7416    19137238           Private Guesthouse in the City of Trees!
# 135396  29853236  PRO-CLEAN near US Capitol, Metro & Shops/PARK ...
# 83442   46356980  KAVO Calista | Gym | Pool | Jacuzzi | Balcony ...
# 206096  47374576      Bright + Clean Studio Loft in Downtown Boston
# 52577   17721493                               Venice Brooks Chalet
#
#           host_id  neighbourhood_group               neighbourhood  latitude  \
# 186785   57387860                  NaN             Near North Side  41.89230
# 125702      24281                  NaN        Unincorporated Areas  37.00939
# 63769   229716119  City of Los Angeles                    Westlake  34.05981
# 17954   229716119  City of Los Angeles                    Westlake  34.05981
# 222414  263748930                  NaN        Unincorporated Areas  36.14215
# ...           ...                  ...                         ...       ...
# 7416      9020570         Other Cities              South Pasadena  34.11690
# 135396   69203193                  NaN  Capitol Hill, Lincoln Park  38.88059
# 83442    48631940                  NaN                  Costa Mesa  33.67545
# 206096  382451810                  NaN              East Cambridge  42.35522
# 52577    23118355  City of Los Angeles                      Venice  33.99718
#
#         longitude        room_type  price  minimum_nights  number_of_reviews  \
# 186785  -87.62734       Hotel room    284               1               2600
# 125702 -121.88547  Entire home/apt    159               2               1724
# 63769  -118.26963  Entire home/apt    113               1               1702
# 17954  -118.26963  Entire home/apt    113               1               1702
# 222414 -115.15706     Private room    238               1               1542
# ...           ...              ...    ...             ...                ...
# 7416   -118.14374  Entire home/apt    130               2                100
# 135396  -76.99239  Entire home/apt    299              31                100
# 83442  -117.88517  Entire home/apt    253               2                100
# 206096  -71.05798  Entire home/apt    266               1                100
# 52577  -118.46381  Entire home/apt    179              30                100
#
#        last_review  reviews_per_month  calculated_host_listings_count  \
# 186785  2022-08-30              55.71                              24
# 125702  2022-09-25              10.73                               2
# 63769   2022-09-06              56.17                               5
# 17954   2022-09-06              56.17                               5
# 222414  2022-09-05              83.80                              11
# ...            ...                ...                             ...
# 7416    2022-08-22               2.02                               1
# 135396  2022-05-07               2.14                              33
# 83442   2022-08-27               4.52                               2
# 206096  2022-09-15               5.46                              47
# 52577   2022-08-24               1.54                              43
#
#         availability_365
# 186785               346
# 125702               100
# 63769                124
# 17954                124
# 222414               298
# ...                  ...
# 7416                 300
# 135396               339
# 83442                268
# 206096               127
# 52577                324
#
# [38907 rows x 15 columns]

# %%
# Save the cleaned, filtered, and sorted data to a new CSV file
filtered_airbnb_data.to_csv('Resources/cleaned_airbnb_listings_usa.csv', index=False)
